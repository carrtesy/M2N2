# %%
# %cd ..
# %ls
# Out:
# C:\Users\Dongmin Kim\Documents\OnlineTSAD
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 067D-FB3E
#
#  C:\Users\Dongmin Kim\Documents\OnlineTSAD 디렉터리
#
# 2023-03-31  오후 06:12    <DIR>          .
# 2023-03-31  오후 06:12    <DIR>          ..
# 2023-03-17  오후 04:13               141 .gitignore
# 2023-04-02  오후 02:39    <DIR>          .idea
# 2023-03-31  오후 06:10    <DIR>          cfgs
# 2023-03-24  오후 05:58    <DIR>          checkpoints
# 2023-04-02  오후 02:37    <DIR>          data
# 2023-04-02  오후 02:44    <DIR>          EDA
# 2023-03-31  오후 05:51    <DIR>          Exp
# 2023-03-24  오후 05:58    <DIR>          logs
# 2023-03-29  오후 02:06    <DIR>          models
# 2023-03-24  오후 05:58    <DIR>          outputs
# 2023-03-24  오후 05:58    <DIR>          plots
# 2023-03-24  오후 05:58    <DIR>          results
# 2023-03-31  오후 06:12             3,657 test.py
# 2023-03-15  오후 03:49             3,099 train.py
# 2023-03-30  오후 02:07    <DIR>          utils
#                3개 파일               6,897 바이트
# ...

# %%
import numpy as np
import pandas as pd

# %%
data_df = pd.read_csv("data/CreditCard/creditcard.csv", index_col=0)
data_df
# Out:
#                  V1         V2        V3        V4        V5        V6  \
# Time
# 0.0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 0.0        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 1.0       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 1.0       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 2.0       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...             ...        ...       ...       ...       ...       ...
# 172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#                 V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
for col in data_df:
    print(f"col:{col} | {data_df[col].isna().sum()}")
# Out:
# col:V1 | 0
# col:V2 | 0
# col:V3 | 0
# col:V4 | 0
# col:V5 | 0
# col:V6 | 0
# col:V7 | 0
# col:V8 | 0
# col:V9 | 0
# col:V10 | 0
# col:V11 | 0
# col:V12 | 0
# col:V13 | 0
# col:V14 | 0
# col:V15 | 0
# col:V16 | 0
# col:V17 | 0
# col:V18 | 0
# col:V19 | 0
# col:V20 | 0
# col:V21 | 0
# col:V22 | 0
# col:V23 | 0
# col:V24 | 0
# col:V25 | 0
# col:V26 | 0
# col:V27 | 0
# col:V28 | 0
# col:Amount | 0
# col:Class | 0

# %%
N = len(data_df)

X, y = data_df.values[:, 0:-1].astype(np.float32), data_df.values[:,-1].astype(int)

train_X, test_X = X[:N//2], X[N//2:]
T, C = train_X.shape
train_y, test_y = y[:N//2], y[N//2:]

# %%
train_X.shape
# Out:
# (142403, 29)

# %%
test_X.shape
# Out:
# (142404, 29)

# %%
train_y.shape
# Out:
# (142403,)

# %%
test_y.shape
# Out:
# (142404,)

# %%
test_y.sum()
# Out:
# 223

# %%
test_y.sum()/len(test_y)
# Out:
# 0.0015659672481110082
